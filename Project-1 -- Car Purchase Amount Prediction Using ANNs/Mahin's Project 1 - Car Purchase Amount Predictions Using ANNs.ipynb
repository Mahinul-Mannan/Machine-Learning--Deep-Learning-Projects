# %% [markdown]
# # Car Purchase Amount Prediction Using ANNs - By Mahinul Mannan.
#
# ## **Author:** Mahinul Mannan
#  **Date:** October 2024
#
# **Project Overview:**
# This project uses an artificial neural network (ANN) to predict car purchase amounts based on customer data. The model takes various features, such as customer age, annual salary, and credit score, to provide an accurate estimate of the purchase amount. By analyzing historical purchase data, this project aims to demonstrate how deep learning can be applied in real-world scenarios, especially in the automotive industry.
#
# **Objectives:**
# - Explore and preprocess the dataset to understand the distribution and relationship of features.
# - Build, train, and optimize an ANN to accurately predict purchase amounts.
# - Evaluate model performance using various metrics and test with new data.
#
# **Technologies Used:**
# - Python, TensorFlow, Keras, Pandas, Matplotlib, Seaborn

# %% [markdown]
# ### PROBLEM STATEMENT

# %% [markdown]
# Suppose a car salesman would like to develop a model to predict the total dollar amount that customers are willing to pay given the following attributes:
# - Customer Name
# - Customer e-mail
# - Country
# - Gender
# - Age
# - Annual Salary
# - Credit Card Debt
# - Net Worth
#
# The model should predict:
# - Car Purchase Amount

# %% [markdown]
# # Project Overview
# ## Goals
# The primary goal of this project is to predict car purchase amounts based on customer information using an Artificial Neural Network (ANN) model. This model can help automotive businesses better understand purchasing trends, enabling them to make data-driven decisions in areas like pricing and customer targeting.
#
# ## Dataset
# The dataset includes various customer features, such as:
#
# **Age:** Customer age, which may correlate with purchasing power.
#
# **Annual Income:** Provides insight into spending capacity.
#
# **Credit Score:** Helps assess customer reliability.
#
# **Gender:** An additional demographic factor.
#
# Each of these features contributes to predicting the target variable, Car Purchase Amount. This data has been preprocessed for model training.
#
# ## Model Purpose
# Here I am using an ANN to uncover complex, non-linear relationships in the data. ANNs are particularly effective in regression tasks and are well-suited for this use case.
#
# ## Outline
# This project follows these main steps:
#
# Exploratory Data Analysis (EDA): Understanding feature distributions and examining correlations to guide model building.
# Data Preprocessing: Preparing data by scaling and encoding features.
# Model Building: Designing a multi-layered ANN for regression.
# Training and Evaluation: Training the model and evaluating its performance with relevant metrics.
# Testing with New Data: Demonstrating the model’s predictive power with unseen data.
# Exploratory Data Analysis (EDA)
# This section explores the dataset’s structure and relationships. Here I examine feature distributions, identify any patterns, and assess correlations to better understand the data's impact on the target variable.
#
# ## Data Preprocessing
# To prepare the data for optimal model performance, this section covers:
#
# Handling Missing Values: Cleaning any missing or anomalous data.
# Feature Scaling: Standardizing numerical features for consistent scale across the dataset.
# Encoding: Converting categorical variables into numerical format for use in the ANN model.
# Train-Test Split: Dividing the dataset into training and testing subsets to evaluate the model's generalization ability.
# Model Building
# Here, I define and compile an ANN model using TensorFlow and Keras libraries. The architecture includes:
#
# Input Layer: 5 input features
# Hidden Layers: Two hidden layers with ReLU activation, each having 25 nodes to capture complex interactions.
# Output Layer: Single node with a linear activation function for regression.
# These choices were made to handle the complexity of predicting a continuous value in a regression setting. Experimenting with additional layers or nodes could further improve accuracy.
#
# ## Training and Evaluation
# This section covers the training process, where the model learns patterns in the training data. Evaluation is done using metrics such as:
#
# Mean Absolute Error (MAE): Measures average absolute errors, providing insight into prediction accuracy.
# Mean Squared Error (MSE): Captures the average squared difference between predictions and actual values.
# These metrics provide a comprehensive assessment of the model’s performance.
#
# ## Results Visualization and Interpretation
# To better interpret results, visualizations such as predicted vs. actual values or error distributions are provided. This helps validate model performance and identifies potential areas of improvement.
#
# ## Testing with New Data
# Finally, I validate the model by predicting car purchase amounts on a new dataset. This test demonstrates the model’s practical application and its ability to generalize to unseen data.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # STEP #0: LIBRARIES IMPORT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # STEP #1: IMPORT DATASET

# %%
car_df = pd.read_csv('Car_Purchasing_Data.csv', encoding='ISO-8859-1')

# %%
car_df

# %% [markdown]
# # STEP #2: VISUALIZE DATASET

# %%
sns.pairplot(car_df)

# %% [markdown]
# # STEP #3: CREATE TESTING AND TRAINING DATASET/DATA CLEANING

# %%
X = car_df.drop(['Customer Name', 'Customer e-mail', 'Country', 'Car Purchase Amount'], axis = 1)

# %%
X

# %%
y = car_df['Car Purchase Amount']
y.shape

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
scaler.data_max_

# %%
scaler.data_min_

# %%
print(X_scaled[:,0])

# %%
y.shape

# %%
y = y.values.reshape(-1,1)

# %%
y.shape

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled

# %% [markdown]
# # STEP#4: TRAINING THE MODEL

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler

model = Sequential()
model.add(Dense(25, input_dim=5, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs=20, batch_size=25,  verbose=1, validation_split=0.2)

# %% [markdown]
# # STEP#5: EVALUATING THE MODEL

# %%
print(epochs_hist.history.keys())

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progression During Training/Validation')
plt.ylabel('Training and Validation Losses')
plt.xlabel('Epoch Number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# Gender, Age, Annual Salary, Credit Card Debt, Net Worth

X_Testing = np.array([[1, 50, 50000, 10985, 629312]])

# %%
y_predict = model.predict(X_Testing)
y_predict.shape

# %%
print('Expected Purchase Amount=', y_predict[:,0])

# %% [markdown]
# # THIS IS THE USE OF ANNs FOR REGRESSION TASKS.

# %% [markdown]
# # ------------------------------------THANK YOU -------------------------------------
